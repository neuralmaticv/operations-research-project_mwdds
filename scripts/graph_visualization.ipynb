# %%
import os
from graph_plotter import plot_graph
from graph_reader import read_graph

# %%
dim_path = "../instances/level0"

for instance in os.listdir(os.path.abspath(dim_path)):
    if instance != "imgs":
        instance_path = os.path.join(dim_path, instance)
        graph_v, graph_e = read_graph(instance_path, False)
        plot_graph(graph_v, graph_e, [], "")
